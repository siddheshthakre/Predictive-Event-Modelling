# %%
import numpy as np 
import pandas as pd

df1 =pd.read_csv("../data/VideoStarted.csv")
df2 = pd.read_csv("../data/VideoDetails.csv")
print("VideoStarted Dataset")
df1.head(10)
# Out:
# VideoStarted Dataset
#                              UserId      Date  Minute_Of_Day  Second  State  \
# 0  0280dfdd112732a3ac12b12dc770b7af  20170106              0       8     35
# 1  435d41ae019cb8db785483793859c9a8  20170106              0      28     35
# 2  1faf0ce0b98e02e1568702f516f01a78  20170106              0      36     35
# 3  3ec691b9d2b5d53ef965fe59b1900b30  20170106              0      48     35
# 4  ff230d487a7139b65f33b54a4cbd2d9e  20170106              0      56     35
# 5  13d9f55e297d7d9c219fbe9085e1006c  20170106              1      24     35
# 6  ca601ff304bf0c0836f8a59f7751b8de  20170106              1      40     35
# 7  f717dc3f757dc18cc0c3f27ed3e94ef8  20170106              1      40     35
# 8  f717dc3f757dc18cc0c3f27ed3e94ef8  20170106              1      40     35
# 9  0d2717ba754737c78430788ed77a1db7  20170106              1      44     35
#
#               Genre  Category ProgramType  Country  Device  OS  \
# ...

# %%
df1.shape
# Out:
# (1796525, 12)

# %%
df2.shape
# Out:
# (3695451, 12)

# %% [markdown]
# # VideoDetails Dataset

# %%
df2.shape

# %%
df2.head(15)
# Out:
#                               UserId      Date  Minute_Of_Day  Second  State  \
# 0   dc93d200565e5bf6e6fc55adb1c5ba06  20170106              0       4     35
# 1   12060efd8b68ea562b265d0129a8af1f  20170106              0      16     35
# 2   9151ab2a901458f27e36548d4a8dc011  20170106              0      20      0
# 3   1faf0ce0b98e02e1568702f516f01a78  20170106              0      20     35
# 4   435d41ae019cb8db785483793859c9a8  20170106              0      20     35
# 5   434200a07e2d14835580cee9ddcf978c  20170106              0      24      0
# 6   1faf0ce0b98e02e1568702f516f01a78  20170106              0      28     35
# 7   3ec691b9d2b5d53ef965fe59b1900b30  20170106              0      40     35
# 8   9151ab2a901458f27e36548d4a8dc011  20170106              0      44      0
# 9   cc3c6d5497235af3c445f41296a4e81f  20170106              0      44      0
# 10  789aa3970808b9c006306f08db926b41  20170106              0      44     38
# ...

# %%
df2.tail(15)

# %%
df2['Start_Time_hr'] = df2['Minute_Of_Day']//60
df2['Start_Time_min'] = df2['Minute_Of_Day']%60
df2['Start_Time_sec'] = df2['Second']
df2 = df2.drop(columns = 'Minute_Of_Day')
df2 = df2.drop(columns = 'Second')
df2.head(15)
# Out:
#                               UserId      Date  State       Genre  Category  \
# 0   dc93d200565e5bf6e6fc55adb1c5ba06  20170106     35      Drama       vod
# 1   12060efd8b68ea562b265d0129a8af1f  20170106     35     Horror       vod
# 2   9151ab2a901458f27e36548d4a8dc011  20170106      0      Drama       vod
# 3   1faf0ce0b98e02e1568702f516f01a78  20170106     35      Drama       vod
# 4   435d41ae019cb8db785483793859c9a8  20170106     35      Anime       vod
# 5   434200a07e2d14835580cee9ddcf978c  20170106      0   Thriller       vod
# 6   1faf0ce0b98e02e1568702f516f01a78  20170106     35      Drama       vod
# 7   3ec691b9d2b5d53ef965fe59b1900b30  20170106     35      Drama       vod
# 8   9151ab2a901458f27e36548d4a8dc011  20170106      0      Drama       vod
# 9   cc3c6d5497235af3c445f41296a4e81f  20170106      0      Drama       vod
# 10  789aa3970808b9c006306f08db926b41  20170106     38      Drama       vod
# ...

# %%
df2['Country_State'] = (str(df2['Country']) + str(df2['State']))
df2.head(5)
# Out:
#                              UserId      Date  State     Genre Category  \
# 0  dc93d200565e5bf6e6fc55adb1c5ba06  20170106     35    Drama      vod
# 1  12060efd8b68ea562b265d0129a8af1f  20170106     35   Horror      vod
# 2  9151ab2a901458f27e36548d4a8dc011  20170106      0    Drama      vod
# 3  1faf0ce0b98e02e1568702f516f01a78  20170106     35    Drama      vod
# 4  435d41ae019cb8db785483793859c9a8  20170106     35    Anime      vod
#
#   ProgramType  Country  Device  OS                           VideoId  \
# 0   TV Shows         1       2   1  1f2dc23e0d2415353982cfa38cbaf983
# 1     Movies         1       1   1  6c95441f239cebf9930ac5932cc84a7f
# 2   TV Shows       255       1   1  1af000794c63fa2722e22af609ff572c
# 3   TV Shows         1       1   1  f053c42e98d50e06532ce8d65afb3ab3
# 4   TV Shows         1       1   1  2a9d984659afc14f801548dd71ddad0e
#
#    Start_Time_hr  Start_Time_min  Start_Time_sec  \
# 0              0               0               4
# ...

# %% [markdown]
# # No. of Unique Values

# %%
print(df2.shape)
df2.nunique()
# Out:
# (3695451, 13)
# UserId            252030
# Date                 158
# State                104
# Genre                 53
# Category               2
# ProgramType            4
# Country               29
# Device                 4
# OS                     3
# VideoId             3856
# Start_Time_hr         24
# Start_Time_min        60
# Start_Time_sec        15
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
z1= df2.nunique()
sns.distplot(z1,kde=True)
# Out:
# C:\Users\SANKALP\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import seaborn as sns

# %%
##COUNTPLOT OF COUNTRIES
a = sns.countplot(df2.Country)
a.figure.savefig("output.png")

# %%
###VALUECOUNT OF COUNTRIES
df2.Country.value_counts()
# Out:
# 1      2688671
# 40      928251
# 255      66443
# 14        4393
# 2         2797
# 30        2399
# 47         586
# 0          494
# 46         398
# 12         209
# 15         190
# 16         137
# 5          132
# 7           61
# 10          51
# 74          40
# 73          36
# 9           36
# 57          27
# 65          27
# 11          16
# 54          13
# 29          10
# 36          10
# 23           9
# 86           6
# 24           5
# 42           3
# 39           1
# Name: Country, dtype: int64

# %%
df2['VideoId'].value_counts().head(5)
# Out:
# 82114e85b433b5b2f9e400b5a07dc8b8    402874
# 42d90a79258cb9bc8c0da5e0aab97237    266009
# ee9b05acd92bcc9b82a58c6c4f8ca610     94415
# 7215ee9c7d9dc229d2921a40e899ec5f     83723
# f053c42e98d50e06532ce8d65afb3ab3     76914
# Name: VideoId, dtype: int64

# %% [markdown]
# # Countrywise Virality

# %%
x=pd.crosstab(index=df2.Country,columns=df2.VideoId,margins = True)
x1 = x.loc[[1,40,255],:]
x1.loc['Total',:]= x1.sum(axis=0)
x1 = pd.DataFrame(x1)

x1.columns
# Out:
# Index(['0002786e6bfa679ca419e2e18fecb42f', '004b1269bca64bd75da73b76061fc25c',
#        '005ebe9a608fe59978ac3c745d3be8ac', '007772c6c02659ad3465b86feb04d703',
#        '007f4fcd1061ed52281afe10f295ff9b', '008732604aded62b5fda3db0db85e1cd',
#        '0092fefbb1024661c8d04e8484facf51', '00a3a04e11ce9c387d5d928ccf1af004',
#        '00bc92230e9f96b8fa73fd89f27e10b9', '00c6ac92c75481e66e0280228c134c7a',
#        ...
#        'ff18c76ebefff4724c71cb66a083c36f', 'ff4056d5469ebf98e2e917c1529cae7b',
#        'ff49250dd0afa21cf45c5555659ea185', 'ff4a8dd7dc0cc649b22d82a38562a825',
#        'ff4d403d152a698f217bc3a958842b61', 'ff6c6d466726d74d57fceeb00147f187',
#        'ff72acc5094f8b064a1747b2c8dbc2ea', 'ff797513b5f6ae966df694e86b2fd6c8',
#        'ff986f6f7637a1cc834452e748611d6a', 'All'],
#       dtype='object', name='VideoId', length=3857)

# %%
x1.drop(columns = 'All',inplace = True)
x1
# Out:
# VideoId  0002786e6bfa679ca419e2e18fecb42f  004b1269bca64bd75da73b76061fc25c  \
# Country
# 1                                     0.0                              19.0
# 40                                    3.0                               0.0
# 255                                   0.0                               0.0
# Total                                 3.0                              19.0
#
# VideoId  005ebe9a608fe59978ac3c745d3be8ac  007772c6c02659ad3465b86feb04d703  \
# Country
# 1                                    50.0                             260.0
# 40                                   14.0                             242.0
# 255                                   6.0                              20.0
# Total                                70.0                             522.0
#
# VideoId  007f4fcd1061ed52281afe10f295ff9b  008732604aded62b5fda3db0db85e1cd  \
# Country
# 1                                     5.0                               0.0
# ...

# %%
x1['0002786e6bfa679ca419e2e18fecb42f']
# Out:
# Country
# 1        0.0
# 40       3.0
# 255      0.0
# Total    3.0
# Name: 0002786e6bfa679ca419e2e18fecb42f, dtype: float64

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=3695451, step=1)

# %%
x1.rename(columns={'Most_Views':'Most_viewed_Video'},inplace =True)
x1
# Out:
# VideoId  0002786e6bfa679ca419e2e18fecb42f  004b1269bca64bd75da73b76061fc25c  \
# Country
# 1                                     0.0                              19.0
# 40                                    3.0                               0.0
# 255                                   0.0                               0.0
# Total                                 3.0                              19.0
#
# VideoId  005ebe9a608fe59978ac3c745d3be8ac  007772c6c02659ad3465b86feb04d703  \
# Country
# 1                                    50.0                             260.0
# 40                                   14.0                             242.0
# 255                                   6.0                              20.0
# Total                                70.0                             522.0
#
# VideoId  007f4fcd1061ed52281afe10f295ff9b  008732604aded62b5fda3db0db85e1cd  \
# Country
# 1                                     5.0                               0.0
# ...

# %%
x2 = pd.crosstab(index=df2.Country,columns=df2.Genre)
x2 = x2.loc[[1,40,255],:]
x2.loc[:,'Most_Viewed_Genre']= x2.idxmax(axis=1)
x2
# Out:
# Genre          Action    Adventure    Animation    Anime    Athletics   \
# Country
# 1        179     81249           51        17406   212048            6
# 40        93     16608            0        14825   190347            0
# 255       43      5162            0          366     9153            0
#
# Genre     Automotive    Award Show    Badminton    Comedy         ...          \
# Country                                                           ...
# 1                2708            13         2936    146885        ...
# 40                477            26            0     37561        ...
# 255               177            13            0      3421        ...
#
# Genre     Talk Show    Team Sports (Excl. Football)    Tennis / Squash   \
# Country
# 1                590                              28               2034
# 40               182                               0                  0
# 255               57                               3                149
#
# ...

# %%
x2.head()
# Out:
# Genre          Action    Adventure    Animation    Anime    Athletics   \
# Country
# 1        179     81249           51        17406   212048            6
# 40        93     16608            0        14825   190347            0
# 255       43      5162            0          366     9153            0
#
# Genre     Automotive    Award Show    Badminton    Comedy         ...          \
# Country                                                           ...
# 1                2708            13         2936    146885        ...
# 40                477            26            0     37561        ...
# 255               177            13            0      3421        ...
#
# Genre     Talk Show    Team Sports (Excl. Football)    Tennis / Squash   \
# Country
# 1                590                              28               2034
# 40               182                               0                  0
# 255               57                               3                149
#
# ...

# %%
sns.countplot(df2[df2.Country==1].Genre)
plt.xticks(rotation = 90)
plt.title("Countplot for Genre for country 1")
# Out:
# Text(0.5, 1.0, 'countplot for Genre for country 1')

# %%
sns.countplot(df2[df2.Country==40].Genre)
plt.xticks(rotation = 90)
plt.title("countplot for Genre for country 40")
# Out:
# Text(0.5, 1.0, 'countplot for Genre for country 40')

# %%
sns.countplot(df2[df2.Country==255].Genre)
plt.xticks(rotation = 90)
plt.title("countplot for Genre for country 255")
# Out:
# Text(0.5, 1.0, 'countplot for Genre for country 255')

# %%
# sns.countplot(df2.Genre)

fig, ax = pyplot.subplots(figsize=(30,10))
sns.countplot(ax=ax, data=df2.Genre)
plt.xticks(rotation = 90)
plt.figure(figsize=(20,10))
plt.title("Countplot for Genre")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-af9f62a79c36> in <module>
#       1 # sns.countplot(df2.Genre)
#       2
# ----> 3 fig, ax = pyplot.subplots(figsize=(30,10))
#       4 sns.countplot(ax=ax, data=df2.Genre)
#       5 plt.xticks(rotation = 90)
#
# NameError: name 'pyplot' is not defined

# %%
df2['Date'] = df2['Date'].apply(lambda x:str(x)[0:4]+str('/') + str(x)[4:6] + str('/') + str(x)[6:8])
df2['Date'] = pd.to_datetime(df2['Date'])
df2.head(5)
# Out:
#                              UserId       Date  Minute_Of_Day  Second  State  \
# 0  dc93d200565e5bf6e6fc55adb1c5ba06 2017-01-06              0       4     35
# 1  12060efd8b68ea562b265d0129a8af1f 2017-01-06              0      16     35
# 2  9151ab2a901458f27e36548d4a8dc011 2017-01-06              0      20      0
# 3  1faf0ce0b98e02e1568702f516f01a78 2017-01-06              0      20     35
# 4  435d41ae019cb8db785483793859c9a8 2017-01-06              0      20     35
#
#       Genre Category ProgramType  Country  Device  OS  \
# 0    Drama      vod    TV Shows         1       2   1
# 1   Horror      vod      Movies         1       1   1
# 2    Drama      vod    TV Shows       255       1   1
# 3    Drama      vod    TV Shows         1       1   1
# 4    Anime      vod    TV Shows         1       1   1
#
#                             VideoId
# 0  1f2dc23e0d2415353982cfa38cbaf983
# 1  6c95441f239cebf9930ac5932cc84a7f
# 2  1af000794c63fa2722e22af609ff572c
# ...

# %%
df2[df2['VideoId'] =='82114e85b433b5b2f9e400b5a07dc8b8']['Date'].dt.month.value_counts()
# Out:
# 5    302034
# 6     65074
# 4     35764
# 2         1
# 1         1
# Name: Date, dtype: int64

# %%
x3 = pd.DataFrame(df2[df2['VideoId'] =='82114e85b433b5b2f9e400b5a07dc8b8']['Date'].dt.month.value_counts(ascending = True))

plt.plot(['Jan','Feb','Mar','Apr','May','Jun'], [1,1,0,35764,302034,65074], color='green', linestyle='dashed', linewidth = 3, 
         marker='o', markerfacecolor='blue', markersize=12) 
plt.title('Virality of Most Viewed Video(82114e85b433b5b2f9e400b5a07dc8b8) in country 1')
plt.xlabel('MONTH')
plt.ylabel('No. of Views')
# Out:
# Text(0, 0.5, 'No. of Views')

# %%
df2[df2['VideoId'] =='42d90a79258cb9bc8c0da5e0aab97237']['Date'].dt.month.value_counts(ascending = True)
plt.plot(['Jan','Feb','Mar','Apr','May','Jun'], [0,0,36178,99511,98479,31841], color='green', linestyle='dashed', linewidth = 3, 
         marker='o', markerfacecolor='blue', markersize=12) 
plt.title('Virality of Most Viewed Video(82114e85b433b5b2f9e400b5a07dc8b8) in country 40')
plt.xlabel('MONTH')
plt.ylabel('No. of Views')
# Out:
# Text(0, 0.5, 'No. of Views')

# %%
df2[df2['VideoId'] =='f053c42e98d50e06532ce8d65afb3ab3']['Date'].dt.month.value_counts(ascending = True)
plt.plot(['Jan','Feb','Mar','Apr','May','Jun'], [62320,13161,1433,0,0,0], color='green', linestyle='dashed', linewidth = 3, 
         marker='o', markerfacecolor='blue', markersize=12) 
plt.title('Virality of Most Viewed Video(82114e85b433b5b2f9e400b5a07dc8b8) in country 255')
plt.xlabel('MONTH')
plt.ylabel('No. of Views')
# Out:
# Text(0, 0.5, 'No. of Views')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.countplot(df2[df2['VideoId'] =='1f2dc23e0d2415353982cfa38cbaf983']['Date'])

# %%
#checking for video virality
df3=df2
df3.head(15)
df3['Date'] = pd.to_datetime(df2['Date'])
df3[df3['VideoId'] =='82114e85b433b5b2f9e400b5a07dc8b8']['Date'].dt.month.value_counts()
# Out:
# 1    402874
# Name: Date, dtype: int64

# %%
df3[df3['VideoId'] =='82114e85b433b5b2f9e400b5a07dc8b8']['Date']
# Out:
# 312363    1970-01-01 00:00:00.020170131
# 337529    1970-01-01 00:00:00.020170202
# 1244022   1970-01-01 00:00:00.020170419
# 1257339   1970-01-01 00:00:00.020170420
# 1257340   1970-01-01 00:00:00.020170420
# 1262552   1970-01-01 00:00:00.020170420
# 1263781   1970-01-01 00:00:00.020170420
# 1263801   1970-01-01 00:00:00.020170420
# 1263802   1970-01-01 00:00:00.020170420
# 1263823   1970-01-01 00:00:00.020170420
# 1263852   1970-01-01 00:00:00.020170420
# 1263867   1970-01-01 00:00:00.020170420
# 1263936   1970-01-01 00:00:00.020170420
# 1263939   1970-01-01 00:00:00.020170420
# 1263956   1970-01-01 00:00:00.020170420
# 1264017   1970-01-01 00:00:00.020170420
# 1264040   1970-01-01 00:00:00.020170420
# 1264063   1970-01-01 00:00:00.020170420
# 1264133   1970-01-01 00:00:00.020170420
# 1264135   1970-01-01 00:00:00.020170420
# 1264137   1970-01-01 00:00:00.020170420
# 1264140   1970-01-01 00:00:00.020170420
# 1264145   1970-01-01 00:00:00.020170420
# ...
